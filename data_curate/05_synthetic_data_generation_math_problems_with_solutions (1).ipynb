# %% [markdown]
# <img src="./images/DLI_Header.png" style="width: 400px;">

# %% [markdown]
# # 5. Generating Math Problems and Solutions with NeMo Curator
#
# In this notebook, we will demonstrate how to use **NVIDIA NeMo Curator** to generate a set of math problems and their solutions on a specific topic.
#
# The generated outputs will then be evaluated using the **Llama-3.1-nemotron-70b-reward model** to ensure quality and relevance.

# %% [markdown]
# **[5.1 NeMo Curator OpenAI Client](#5.1-NeMo-Curator-OpenAI-Client)<br>**
# **[5.2 Math problems generation in English and Spanish](#5.2-Math-problems-generation-in-English-and-Spanish)<br>**
# **[5.3 Combining subtopics and math problems generation to create a diverse set of math problems in English and Spanish](#5.3-Combining-subtopics-and-math-problems-generation-to-create-a-diverse-set-of-math-problems-in-English-and-Spanish)<br>**

# %% [markdown]
# ---

# %% [markdown]
# ## Connecting to the NVIDIA API Catalog

# %% [markdown]
# NeMo Curator supports connecting to [OpenAI API](https://github.com/openai/openai-python?tab=readme-ov-file#openai-python-api-library) compatible services and [NeMo Deploy](https://docs.nvidia.com/nemo-framework/user-guide/latest/deployingthenemoframeworkmodel.html#use-nemo-export-and-deploy-module-apis-to-run-inference) services.
#
# In this notebook, we rely on the `build.nvidia.com` API endpoints. You can use this same flow with a model deployed as an NVIDIA NIM for LLMs which can be found [here](https://github.com/NVIDIA/NeMo-Curator/blob/main/docs/user-guide/syntheticdata.rst#connecting-to-an-llm-service).

# %% [markdown]
# Your environment already has an NVIDIA API key installed for you. For work outside of this workshop environment, please see the instructions below for how to obtain your own free NVIDIA API key.

# %% [markdown]
# ### Obtaining Your Own NVIDIA API Key

# %% [markdown]
# If you would like an NVIDIA API key for your own work outside this workshop environment, you can generate one for free using the following steps:
#
# 1. Login (or sign up) through [build.nvidia.com](https://build.nvidia.com/explore/discover).
# 2. Click the `Get API Key` button available on the the `Llama 3.1 Nemotron 70B Reward` page, found [here](https://build.nvidia.com/nvidia/llama-3_1-nemotron-70b-reward).

# %% [markdown]
# ---

# %% [markdown]
# ## 5.1 NeMo Curator OpenAI Client
#
# We will begin by initializing NeMo Curator's `OpenAI Client`.
#
# Please note that this step is identical to the process outlined in the previous notebook.

# %% [markdown]
# ### Loading NVIDIA API Credentials
#
# Before connecting to NVIDIA's API, we need to load the required credentials. This cell automatically checks multiple locations:
#
# 1. **Project directory** (priority 1): `./secrets.env` (in the same folder as this notebook) ✅ **Found!**
# 2. **Home directory** (priority 2): `~/.nvidia/secrets.env`
# 3. **Environment variables** (priority 3): Pre-set in some workshop environments
#
# **Required credentials:**
# - `NVIDIA_API_KEY`: Your NVIDIA API key from build.nvidia.com
# - `NVIDIA_BASE_URL`: The NVIDIA API endpoint (https://integrate.api.nvidia.com/v1)
#
# **Get your free API key:**
# Visit https://build.nvidia.com/nvidia/llama-3_1-nemotron-70b-reward and click "Get API Key"

# %%
# Load NVIDIA API credentials from secrets file
import os
from pathlib import Path

# Path to secrets file - check multiple locations
# Priority: 1) Local project directory, 2) Home directory, 3) Environment variables
try:
    project_secrets = Path("secrets.env")
    home_secrets = Path.home() / ".nvidia" / "secrets.env"
except Exception as e:
    print(f"Warning: Path setup issue: {e}")
    project_secrets = None
    home_secrets = None

def load_secrets_from_file(filepath):
    """Load environment variables from a secrets file"""
    try:
        if not filepath or not filepath.exists():
            return False
        
        print(f"Loading secrets from {filepath}")
        with open(filepath, 'r') as f:
            for line in f:
                line = line.strip()
                if line and not line.startswith('#') and '=' in line:
                    key, value = line.split('=', 1)
                    os.environ[key.strip()] = value.strip().strip('"').strip("'")
        print("✓ NVIDIA API credentials loaded")
        return True
    except Exception as e:
        print(f"Error loading secrets: {e}")
        return False

# Try loading from different locations
loaded = False
if project_secrets and project_secrets.exists():
    loaded = load_secrets_from_file(project_secrets)
elif home_secrets and home_secrets.exists():
    loaded = load_secrets_from_file(home_secrets)
elif "NVIDIA_API_KEY" in os.environ:
    print("✓ Using NVIDIA_API_KEY from environment variables")
    loaded = True
else:
    print("⚠️  NVIDIA_API_KEY not found!")
    print("\nSearched locations:")
    print(f"  1. ./secrets.env")
    print(f"  2. ~/.nvidia/secrets.env")
    print(f"  3. Environment variables")
    print("\nPlease create a secrets.env file with:")
    print("   NVIDIA_API_KEY=nvapi-xxxxxxxxxxxxx")
    print("   NVIDIA_BASE_URL=https://integrate.api.nvidia.com/v1")

# Verify credentials are available
if "NVIDIA_API_KEY" in os.environ and "NVIDIA_BASE_URL" in os.environ:
    print(f"\n✓ API Key: {os.environ['NVIDIA_API_KEY'][:10]}...")
    print(f"✓ Base URL: {os.environ['NVIDIA_BASE_URL']}")
else:
    print("\n❌ Missing required environment variables!")
    print("   Required: NVIDIA_API_KEY, NVIDIA_BASE_URL")
# Out:
# Loading secrets from secrets.env
# ✓ NVIDIA API credentials loaded
#
# ✓ API Key: nvapi-vMsg...
# ✓ Base URL: https://integrate.api.nvidia.com/v1

# %%
import os

from nemo_curator import OpenAIClient
from nemo_curator.synthetic import NemotronGenerator
from openai import OpenAI

# Initialize OpenAI's client with the NVIDIA API endpoint and the API key.
openai_client = OpenAI(
    # Outside this workshop environment you would set NVIDIA_BASE_URL to "https://integrate.api.nvidia.com/v1".
    base_url=os.environ["NVIDIA_BASE_URL"],
    api_key=os.environ["NVIDIA_API_KEY"],
)

# Initialize NeMo Curator's OpenAIClient by passing the OpenAI client instance.
# This wraps the OpenAI client to provide additional functionality specific to NeMo Curator.
curator_openai_client = OpenAIClient(openai_client)

# Create an instance of NemotronGenerator, which facilitates synthetic data generation.
generator = NemotronGenerator(curator_openai_client)

# Model used to generate syntethic data.
model = "mistralai/mistral-7b-instruct-v0.3"
model_kwargs = {
    "temperature": 0.1,
    "top_p": 0.9,
    "max_tokens": 1024,
}

# %% [markdown]
# ## 5.2 Math problems generation in English and Spanish
# We will generate math problems based on a specific subtopic. Instead of using the `convert_response_to_yaml_list` method, we will create and use **a custom parser**.
#
# In order to do it, we will slightly modify the default `MATH_PROBLEM_GENERAL_PROMPT_TEMPLATE`, and will use the following instead:
#
# ```python
#     "Create {n_openlines} diverse mathematics problems related to the topic '{topic}' " \
#     "or solvable using concepts from '{topic}'. Provide your response as a numbered list, " \
#     "and include both the problem description and its solution. Format your response as follows: " \
#     "((###1###)) >>>Problem<<<: [Description of the first problem]. >>>Solution<<<: [Solution to the first problem].\n" \
#     "((###2###)) >>>Problem<<<: [Description of the second problem]. >>>Solution<<<: [Solution to the second problem].\n" \
#     "Only include the problems and their solutions—no additional text."
# ```

# %%
math_prompt_template_english = (
    "Create {n_openlines} diverse mathematics problems related to the topic '{topic}' "
    "or solvable using concepts from '{topic}'. Provide your response as a numbered list, "
    "and include both the problem description and its solution. Format your response as follows: "
    "((###1###)) >>>Problem<<<: [Description of the first problem]. >>>Solution<<<: [Solution to the first problem].\n"
    "((###2###)) >>>Problem<<<: [Description of the second problem]. >>>Solution<<<: [Solution to the second problem].\n"
    "Only include the problems and their solutions—no additional text."
)

n_problems = 3
topic = "Algebra"

llm_response = generator.generate_math_problem(
    model=model,
    topic=topic,
    n_openlines=n_problems,
    prompt_template=math_prompt_template_english,
)

print(llm_response[0])
# Out:
# ((###1###))
# >>>Problem<<<: Find the solutions for the quadratic equation 3x² - 4x - 5 = 0.
# >>>Solution<<<: To find the solutions, we need to use the quadratic formula: x = (-b ± √(b² - 4ac)) / (2a). Here, a = 3, b = -4, and c = -5.
# Calculate b² - 4ac = (-4)² - 4 * 3 * (-5) = 16 + 30 = 46.
# Now, find the two solutions:
# x₁ = (-(-4) + √46) / (2 * 3)
# x₁ = (4 + √46) / 6
# x₂ = (-(-4) - √46) / (2 * 3)
# x₂ = (4 - √46) / 6
#
# ((###2###))
# >>>Problem<<<: Solve for x in the linear equation 2(3x + 5) - 7 = 0.
# >>>Solution<<<: First, notice that parentheses are needed to distribute the -7 to each term within the parentheses.
# 2(3x + 5) - 7 = 0 becomes 6x + 10 - 7 = 0, which simplifies to 6x = 3.
# Divide both sides by 6, x = 3/6 = 1/2.
#
# ((###3###))
# >>>Problem<<<: If a, b, and c are roots of the equation x³ - 6x² + 11x - 6 = 0, find the values of Sa² + Tb² + Cc². Here, S = a + b + c, T = ab + bc + ca, and C = abc.
# >>>Solution<<<: First, we need to find the roots a, b, and c of the given cubic equation. We will use subsitution method by assuming a = t - 3 and solve for t.
# Replacing x with (t - 3) in the original equation, we have:
# (t - 3)³ - 6[(t - 3)²] + 11[(t - 3)] - 6 = 0
# For convenience, let's replace (t - 3)³ with T, so we have: T - 6T + 11(t - 3) - 6 = 0
# Expand T, we get: t³ - 9t² + 27t - 27 - 6t³ + 36t² - 63t + 36 = 0
# Combine similar terms, we have: t³ - 5t³ + 7t² + 4t - 60 = 0
# Since all coefficients are multiples of t, factor by t, we get: t(t² - 5t² + 7t + 4) - 60 = 0
# Factor the quadratic, we get: t(t - 4)(t + 1) - 60 = 0
# Now, solve for t: t(t - 4)(t + 1) = 60
# Null factors theorem reveals t = 6, -1, and -4 are the roots of t⁴ - 5t³ + 7t² + 4t - 60 = 0.
# Using the substitution, a, b, and c are:
# a = 6 - 3 = 3, b = -1 - 3 = -4, and c = -4
# Now, calculate S, T, and C:
# S = a + b + c = 3 + (-4) + (-4) = -5
# T = ab + bc + ca = 3 * (-4) * (-4) + (-4) * (-4) * 3 + 3 * 3 * (-4) = 96
# C = abc = 3 * (-4) * -4 = 48
# Now calculate Sa² + Tb² + Cc²:
# Sa² = (3)² = 9, Tb² = (-4)² = 16, and Cc² = (-4)³ = -64.
#
# So, Sa² + Tb² + Cc² = 9 + 16 - 64 = -39.

# %% [markdown]
# In this case, we will use a customer parser to clean our list of questions/answers.

# %%
import re
from typing import List, Tuple


def parse_math_llm_response(
    llm_response: str, tag_replacements: dict
) -> List[Tuple[str, str]]:
    # Extract the first and second tags from the tag_replacements dictionary
    first_tag, second_tag = list(tag_replacements.keys())[:2]

    # Regular expression to match each problem-solution block using the first and second tags
    pattern = rf"{re.escape(first_tag)}(.*?){re.escape(second_tag)}(.*?)(?=\(\(###|\Z)"

    # Find all matches using re.DOTALL to handle multiline content
    matches = re.findall(pattern, llm_response, re.DOTALL)

    # Clean up and replace tags in extracted problems and solutions
    problem_solution_pairs = []
    for problem, solution in matches:
        # Replace tags with their corresponding replacements
        for tag, replacement in tag_replacements.items():
            problem = problem.replace(tag, replacement).strip()
            solution = solution.replace(tag, replacement).strip()

        problem_solution_pairs.append((problem.strip(), solution.strip()))

    return problem_solution_pairs


def generate_math_problems(
    model: str,
    model_kwargs: dict,
    topic: str,
    n_problems: int,
    math_prompt_template: str,
    tag_replacements: dict,
    n_retries: int = 5,
) -> List[Tuple[str, str]]:
    math_problems = []
    for _ in range(n_retries):
        try:
            llm_response = generator.generate_math_problem(
                model=model,
                topic=topic,
                n_openlines=n_problems,
                prompt_template=math_prompt_template,
            )
            math_problems = parse_math_llm_response(
                llm_response=llm_response[0], tag_replacements=tag_replacements
            )
            break
        except Exception as e:
            print(f"Hit: {e}, Retrying...")

    return math_problems


# We will use these tags to find the problem and solution
tag_replacements_english = {
    ">>>Problem<<<:": "Problem:",
    ">>>Solution<<<:": "Solution:",
}

# Example usage
math_problems_english = generate_math_problems(
    model=model,
    model_kwargs=model_kwargs,
    topic=topic,
    n_problems=n_problems,
    math_prompt_template=math_prompt_template_english,
    tag_replacements=tag_replacements_english,
)

# Print each problem-solution pair
for idx, (problem, solution) in enumerate(math_problems_english):
    print(f"Problem: {problem}")
    print(f"Solution: {solution}\n")
# Out:
# Problem: Find the solutions for the quadratic equation 3x² - 4x - 5 = 0.
# Solution: To find the solutions, we need to use the quadratic formula: x = (-b ± √(b² - 4ac)) / (2a). Here, a = 3, b = -4, and c = -5.
# Calculate b² - 4ac = (-4)² - 4 * 3 * (-5) = 16 + 30 = 46.
# Now, find the two solutions:
# x₁ = (-(-4) + √46) / (2 * 3)
# x₁ = (4 + √46) / 6
# x₂ = (-(-4) - √46) / (2 * 3)
# x₂ = (4 - √46) / 6
#
# Problem: Solve for x in the linear equation 2(3x + 5) - 7 = 0.
# Solution: First, notice that parentheses are needed to distribute the -7 to each term within the parentheses.
# 2(3x + 5) - 7 = 0 becomes 6x + 10 - 7 = 0, which simplifies to 6x = 3.
# Divide both sides by 6, x = 3/6 = 1/2.
#
# Problem: If a, b, and c are roots of the equation x³ - 6x² + 11x - 6 = 0, find the values of Sa² + Tb² + Cc². Here, S = a + b + c, T = ab + bc + ca, and C = abc.
# Solution: First, we need to find the roots a, b, and c of the given cubic equation. We will use subsitution method by assuming a = t - 3 and solve for t.
# Replacing x with (t - 3) in the original equation, we have:
# (t - 3)³ - 6[(t - 3)²] + 11[(t - 3)] - 6 = 0
# For convenience, let's replace (t - 3)³ with T, so we have: T - 6T + 11(t - 3) - 6 = 0
# Expand T, we get: t³ - 9t² + 27t - 27 - 6t³ + 36t² - 63t + 36 = 0
# Combine similar terms, we have: t³ - 5t³ + 7t² + 4t - 60 = 0
# Since all coefficients are multiples of t, factor by t, we get: t(t² - 5t² + 7t + 4) - 60 = 0
# Factor the quadratic, we get: t(t - 4)(t + 1) - 60 = 0
# Now, solve for t: t(t - 4)(t + 1) = 60
# Null factors theorem reveals t = 6, -1, and -4 are the roots of t⁴ - 5t³ + 7t² + 4t - 60 = 0.
# Using the substitution, a, b, and c are:
# a = 6 - 3 = 3, b = -1 - 3 = -4, and c = -4
# Now, calculate S, T, and C:
# S = a + b + c = 3 + (-4) + (-4) = -5
# T = ab + bc + ca = 3 * (-4) * (-4) + (-4) * (-4) * 3 + 3 * 3 * (-4) = 96
# C = abc = 3 * (-4) * -4 = 48
# Now calculate Sa² + Tb² + Cc²:
# Sa² = (3)² = 9, Tb² = (-4)² = 16, and Cc² = (-4)³ = -64.
#
# So, Sa² + Tb² + Cc² = 9 + 16 - 64 = -39.

# %% [markdown]
# Now it’s time to do the same in Spanish. To accomplish this, we simply need to adjust the prompt as follows:

# %%
math_prompt_template_spanish = (
    "Crea {n_openlines} problemas de matemáticas diversos relacionados con el tema '{topic}' "
    "o que se puedan resolver utilizando conceptos de '{topic}'. Proporciona tu respuesta como una lista numerada, "
    "e incluye tanto la descripción del problema como su solución. Formatea tu respuesta de la siguiente manera: "
    "((###1###)) >>>Problema<<<: [Descripción del primer problema]. >>>Solución<<<: [Solución del primer problema].\n"
    "((###2###)) >>>Problema<<<: [Descripción del segundo problema]. >>>Solución<<<: [Solución del segundo problema].\n"
    "Incluye únicamente los problemas y sus soluciones, sin texto adicional. Responde usando sólo el idioma Español."
)

# We will use these tags to find the problem and solution
tag_replacements_spanish = {
    ">>>Problema<<<:": "Problema:",
    ">>>Solución<<<:": "Solución:",
}

math_problems_spanish = generate_math_problems(
    model=model,
    model_kwargs=model_kwargs,
    topic=topic,
    n_problems=n_problems,
    math_prompt_template=math_prompt_template_spanish,
    tag_replacements=tag_replacements_spanish,
)

# Print each problem-solution pair
for idx, (problem, solution) in enumerate(math_problems_spanish):
    print(f"Problema: {problem}")
    print(f"Solución: {solution}\n")
# Out:
# Problema: Encontrar el valor de las variables en una ecuación cuadrática para que la suma de las raíces sea 10 y sea menor a cero.
# Solución: Si la suma de las raíces es 10, es decir, `x1 + x2 = 10`, y ambas raíces son menores que cero, entonces la ecuación cuadrática tiene que ser del tipo `x² + 10x + c = 0`, donde `c` es un número positivo menor que 100 para que sus raíces sean menores que cero. Por ejemplo, la ecuación `x² + 10x + 25 = 0` tiene soluciones `x1 = -5` y `x2 = -3`, que cumplen con las condiciones.
#
# Problema: Determinar la fórmula de la parábola que tiene un punto cíclico en `(2, 1)` y una distances entropia de `3` desde el origen.
# Solución: La fórmula de la parábola en el sistema cartesiano es de la forma `z = a(x - h)² + k`, donde `(h, k)` es el punto cíclico del parábola y `a` es una constante positiva que determina la distancia entre el origen y el punto cíclico. En nuestro caso, el punto cíclico está en `(2, 1)`, así que si tomamos la distancia sharan hacia el origen, será `³` unidades:`(2 - 0)² + 1 - 0 = 3`. Por lo tanto, `a = 1` y `k = 1`. Así que la ecuación de la parábola es `z = (x - 2)² + 1`.
#
# Problema: Hallar un polinomio de grado 6 y que tiene un raíz después del cuadrado y dos raíces dadas.
# Solución: Si tenemos dos raíces conocidas `x1` y `x2` y queremos hacer un polinomio de sexta grado con una raíz tras el cuadrado, podemos usar la ecuación general de un polinomio de sexta grado: `p(x) = a(x - x1)(x - x2)(x - x3)(x - x4)(x - x5)(x - x6)`, donde `x1`, `x2`, `x3`, `x4`, `x5` y `x6` son las raíces de `p(x)`. Si deseamos que haya una raíz en `x²`, podemos elegir `x3` como la raíz cuadrada: `x3 = sqrt(x2)`. Entonces, tenemos seis raíces dadas, y solo deseamos tres variables en la expresión del polinomio, lanzamos un segmento en la corona, es decir, asignamos una de las nueve posibles raíces a una variable y la eliminamos del polinomio, obteniendo un polinomio de sexta grado con una raíz tras el cuadrado y dos raíces fijas. Por ejemplo, si los raíces son `1`, `3`, `4`, `sqrt(3)`, `sqrt(4)` y `5`, podríamos tomar el último término: `5` y asignarlo a una variable: `p(x) = (x - 1)(x - 3)(x - 4)(x - sqrt(3))^2(x - v)`, donde `v` es el nuevo parámetro del polinomio.

# %% [markdown]
# ## 5.3 Combining subtopics and math problems generation to create a diverse set of math problems in English and Spanish
#
# Now it's time to bring together everything we've covered so far. To achieve this, we will begin by generating a list of `n` math subtopics and then create `m` pairs of problem-solution sets for each subtopic.
#
# Let's begin with the English language!

# %%
from utils import generate_subtopics


def math_pipeline(
    generator: NemotronGenerator,
    model: str,
    model_kwargs: dict,
    topic: str,
    n_subtopics: int,
    n_problems: int,
    subtopics_prompt_template: str,
    math_prompt_template: str,
    tag_replacements: dict,
    n_retries: int = 5,
) -> List[Tuple[str, str]]:

    # Generate n math subtopic
    print(f"Generating {n_subtopics} subtopics for {topic}...")
    subtopics = generate_subtopics(
        generator=generator,
        model=model,
        model_kwargs=model_kwargs,
        macro_topic=topic,
        n_subtopics=n_subtopics,
        prompt_template=subtopics_prompt_template,
    )

    # Print the subtopics
    for subtopic in subtopics:
        print(f"\t{subtopic}")

    # Convert tag_replacements values to list, to use in the next step
    tag_replacements_values = list(tag_replacements.values())

    # Generate n problems per subtopic
    math_problems = []
    for subtopic in subtopics:
        print(f"\nGenerating {n_problems} {subtopic} problem-solution pair(s)...")
        try:
            llm_response = generate_math_problems(
                model=model,
                model_kwargs=model_kwargs,
                topic=subtopic,
                n_problems=n_problems,
                math_prompt_template=math_prompt_template,
                tag_replacements=tag_replacements,
            )

            # Print each problem-solution pair
            for idx, (problem, solution) in enumerate(llm_response):
                print(f"{tag_replacements_values[0]} {problem}")
                print(f"{tag_replacements_values[1]} {solution}\n")

            math_problems.extend(llm_response)
        except Exception as e:
            print(f"Hit: {e}")

    return math_problems


# Define a prompt template for generating subtopics in English.
subtopics_prompt_template_english = (
    "Generate {n_subtopics} topics that cover various aspects of {macro_topic}. "
    "Your response should only be a list of topics, as diverse as possible. Do not include explanations or additional text. For example: "
    "1. Food and drinks. \n2. Technology.\n"
)

topic_english = "Math"
n_subtopics = 3
n_problems = 3

# Run the pipeline for English
math_problems_english = math_pipeline(
    generator=generator,
    model=model,
    model_kwargs=model_kwargs,
    topic=topic_english,
    n_subtopics=n_subtopics,
    n_problems=n_problems,
    subtopics_prompt_template=subtopics_prompt_template_english,
    math_prompt_template=math_prompt_template_english,
    tag_replacements=tag_replacements_english,
)
# Out:
# Generating 3 subtopics for Math...
# 	Calculus Applications in Physics
# 	Geometry in Architecture
# 	Probability and Statistics in Finance
#
# Generating 3 Calculus Applications in Physics problem-solution pair(s)...
# Problem: Find the velocity of an object moving with acceleration a(t) = t^2 + 3t, if the initial velocity is 0 at t=0.
# Solution: Since the initial velocity is 0, we need to find the definite integral of acceleration from 0 to t, which gives us the velocity at time t.
#
#     v(t) = ∫a(t) dt = ∫(t^2 + 3t) dt = (t^3/3 + 3t^2/2) + C
#
#     Since v(0) = 0, we find the constant of integration, C, to be 0. So, the velocity function becomes v(t) = (t^3/3 + 3t^2/2).
#
# Problem: A spring is stretched with a force F(x) = 5x^3 - 3x^2, where F is in Newtons and x is measured in meters. Determine how far the spring will be stretched when a force of 10 Newton is applied.
# Solution: To find the displacement (x) where F(x) = 10 N, we need to solve the equation 5x^3 - 3x^2 - 10 = 0. This is a cubic equation, which can be solved numerically or through the use of a calculator. Solving this equation gives us two real roots, but since the spring can't be stretched beyond its natural length, we consider the positive root as the solution: x ≈ 0.8205 meters.
#
# Problem: Calculate the work done to move a 6-kg mass from height h1 = 2m to height h2 = 4m, given the potential energy function U(x) = -mgh, where g is the gravitational acceleration.
# Solution: The work done is the difference in potential energy between the initial and final positions. Let's calculate the potential energy at both heights and take the difference.
#
#     U(h1) = -mgh1 = -6gh1
#     U(h2) = -mgh2 = -6gh2
#
#     Then, the work done, W, is the difference in these quantities:
#
#     W = U(h2) - U(h1) = -6gh2 + 6gh1 = -6g(h2 - h1) = -6g * 2m = -12mg Joules.
#
#
# Generating 3 Geometry in Architecture problem-solution pair(s)...
# Problem: Design a rectangular floor plan for a building. The dimensions of the floor should be 50m by 80m. Determine the area and the perimeter of this floor plan.
# Solution: The area of the rectangle can be calculated using the formula: Area = Length * Width. In this case, the area is 50m * 80m = 4000m². The perimeter of a rectangle can be calculated using the formula: Perimeter = 2 * (Length + Width). In this case, the perimeter is 2 * (50m + 80m) = 260m.
#
# Problem: An architect wants to create a triangular courtyard with equal base and height. The area of the courtyard should be 729 square meters. What should be the length of the base and height of the triangle?
# Solution: The area of an equilateral triangle can be calculated using the formula: Area = √(3)/4 * Side² . In this case, we want the area of the triangle to be 729m². Solving the equation gives us Side = √(4 * 729 * 4 / √(3)) = 27m (rounded). Since the base and height are equal, the base and height of the triangle should both be 27m.
#
# Problem: A miniature model of a pyramid is designed for a scale of 1:100. The base of the pyramid has a diameter of 400mm. What is the height of the pyramid in accurately scaled dimensions? Assume the pyramid to be a regular tapered pyramid.
# Solution: A regular tapered pyramid has a square base. The area of a square can be calculated using the formula: Area = Side² . Given the base diameter of 400mm, the side length of the base square would be 200mm. To find the height of the pyramid, we know that the slant height (h) satisfies h² + (Side/2)² = (Height/2)² where Height is the height of the pyramid. In this case, for a 1:100 scale model: Height_model = 100 * Height_original. Let's solve for Height: h² + (200mm/2)² = (100 * Height_original/2)² . Solving this equation gives us Height_original ≈ 4000mm, or 40cm, when converted from millimeters to centimeters. The scaled height would be 100 * 40cm = 4000mm or 40m.
#
#
# Generating 3 Probability and Statistics in Finance problem-solution pair(s)...
# Problem: If a stock's annual return has a standard deviation of 25% and a mean return of 10%, calculate the annual volatility rate of this stock.
# Solution: The volatility rate (annual standard deviation) can be calculated directly from the given standard deviation. The volatility rate is 25%.
#
# Problem: A financial analyst estimates the normal distribution of monthly returns for a certain stock. If the mean return is 1.5% and the standard deviation is 2.0%, calculate the probability that the stock's monthly return will be greater than 3.5%.
# Solution: To find the probability, we can use the cumulative distribution function (CDF) of the standard normal distribution. First, we need to standardize the given value (3.5%) and the mean (1.5%) using the formula z = (x - μ) / σ, where x is the value we want to find the probability for (3.5%), μ is the mean (1.5%), and σ is the standard deviation (2.0%).
#
# After standardization, we get z = (3.5 - 1.5) / 2 = 1.0. Now we find the probability in a standard normal distribution table or using a calculator with the CDF function, which results in P(z > 1.0) = 0.158655. However, we want the probability that the return is greater than 3.5%, not less than -3.5%, so we subtract the value obtained from the probability table, which gives P(Monthly return > 3.5%) = 1 - P(z <= 1.0) = 1 - 0.158655 = 0.841345 or 84.1345%.
#
# Problem: A biotech company's R&D project has an 80% probability of successfully developing a new drug within 3 years. If the total cost of the R&D project is $60 million, calculate the expected monetary value (EMV) of this R&D project.
# Solution: The expected monetary value (EMV) is the sum of the value multiplied by the probability of each possible outcome. Since there are only two outcomes in this case (success or failure), we can calculate the EMV as follows:
#
# If the project is successful, the value is assumed to be $150 million (the benefit from the successful development of the new drug). The probability of success is 0.80. So the EMV for success is 0.80 * $150 million = $120 million.
#
# If the project fails, the value is the loss incurred, which is the initial cost of the R&D project. So the EMV for failure is 0.20 * ($60 million) = -$12 million.
#
# EMV = EMV (success) + EMV (failure) = $120 million - $12 million = $108 million. This is the expected monetary value for this R&D project.

# %%
# Define a prompt template for generating subtopics in Spanish.
subtopics_prompt_template_spanish = (
    "Genera {n_subtopics} temas amplios que abarquen diversos aspectos de {macro_topic}. "
    "Tu respuesta debe ser únicamente una lista de temas. "
    "Cada tema es un elemento de la lista. No incluyas subtemas ni explicaciones ni texto adicional. "
    "Por ejemplo: 1. Comida y bebidas. \n2. Tecnología.\n"
)

# Run the pipeline for Spanish
topic_spanish = "Matemáticas"
math_problems_spanish = math_pipeline(
    generator=generator,
    model=model,
    model_kwargs=model_kwargs,
    topic=topic_spanish,
    n_subtopics=n_subtopics,
    n_problems=n_problems,
    subtopics_prompt_template=subtopics_prompt_template_spanish,
    math_prompt_template=math_prompt_template_spanish,
    tag_replacements=tag_replacements_spanish,
)
# Out:
# Generating 3 subtopics for Matemáticas...
# 	Álgebra Lineal
# 	Análisis Matemático
# 	Geometría y Topología
#
# Generating 3 Álgebra Lineal problem-solution pair(s)...
# Problema: Encontrar la ecuación de la recta que pasa por los puntos (1,3) y (4,5).
# Solución: Primero encontramos el gradiente de la recta: m = (y2 - y1) / (x2 - x1) = (5 - 3) / (4 - 1) = 2/3. Luego, encontramos el punto en coordenadas (x1, y1) y lo usamos para encontrar el coeficiente a de la ecuación general de una recta: y - y1 = m(x - x1), es decir, a = -m*x1 + y1. Sustituyendo los valores en (1,3), obtendremos a = -(2/3)*1 + 3 = 5/3. Así, la ecuación general de la recta es y = (5/3)x + (3 - (5/3)*1).
#
# Problema: Determinar el valor de la tiene las cuatro matrices A, B, C y D, dado que existen tal que AB - AC = BD.
# Solución: La relación dada tiene la siguiente forma: AB - AC = BD. Se podría reescribir esta relación como A(B - C) = BD. Dado que la multiplicación de matrices no es definida sin un orden de multiplicación predeterminado, podemos definir el orden como A, luego B, luego C y por último D. También podemos supuestos que hay matrices inversibles I squeezed entre los factores no multiplicados. Resulta: AIB - AIC = BDI. Cancelando las I: A(BI - C) = BD. Por lo tanto, SI(BI - C) = SD, con S y D dos matrices. Ahora, podemos reencontrar la relación original multiplicando ambos miembros por I: (BI - C) = S^{-1}D. Luego, podemos averiguar los valores respectivos de las matrices S y D cubriendo el lado izquierdo e izquierdo con unidades; en otras palabras, BI y C están en términos de A (tal cual se puede ver puesto que la relación no considera cero), por lo que B, C y D dependen de A.
#
# Problema: Hallar la matriz A tal que la ecuación AX = 0 tiene solución no trivial para la matriz X = [3 -2 1; 4 1 5; 0 2 1].
# Solución: Para encontrar la matriz A, tenemos que encontrar una combinación no trivial de las columnas de A tal que prodcuto entre este conjunto y cualquier matriz X sea cero. Una posible solución es Tocherowitz: Arreglado las columnas en una sola matriz, hallar los compinentes de la fila 1 y cortarlos con el vector unitario relativo a la fila 1 aproximadamente perpendicular en el espacio vectorial que consta de las columnas sino mencionadas en la matriz A. Después de realizar esto con las columnas 2 y 3, obtenemos que, en caso de tener una solución no trivial, la primera fila debe ser cero, es decir:
#
# A = [0 x y]
#
# Donde x es el producto vectorial entre las columnas 2 y 3, mientras que y es la forma escalar entre la columna 1 y el vector resultante. También podemos establecer:
#
# x = [a b c]
#
# Dado que la muestra suma vectorial de x, en términos de la normalidad del espacio en el vector menor o igual a cero si y solo si las entradas de x son no positivas. Además, x es perpendicular al vector [3,4,0] si y sólo si [a*3 + b*4 + c*0] = 0. Entonces, obtenemos las siguientes ecuaciones:
#
# - a + 2b + c = 0
# - 3a + 4b = 0
# - c = 0
#
# Y como la ecuación 3 no tiene ninguna restricción, al menos uno de los valores de b,c y a son cero. En este caso, asumiendo que c = 0, tendremos que cielar la siguiente ecuación:
#
# -a - 2b = 0
#
# La solución a esta ecuación es b = a/2. Por lo tanto, tendremos dos soluciones posibles (una para a = 1 y otra para a = -1). Para completar la matriz A tendremos que elegir alguna combinación con las columnas 2 y 3, pero no las podemos considerar ya que su unico posible producto vectorial es cero. En consecuencia, considerando que a = 1, podemos elegir alguna combinación arbitraria con las columnas 2 y 3 tal que la matriz A quede como la siguiente:
#
# A = [[0, 1, -1]; [0, 2, -2]; [0, 0, 0]]
#
#
# Generating 3 Análisis Matemático problem-solution pair(s)...
# Problema: Encontrar la función contenida entre los bordes de dos convexos diferentes en el plano que se intersecan solo en un punto M, de manera que la función sea continuamente diferenciable todas partes excepto en el punto M, donde sea derivada descontinua.
# Solución: Se puede definir una función candidata como $f(x,y) = \frac{1}{\left|x-a\right|^{2/3}} - \frac{1}{\left|x-b\right|^{2/3}}$, donde $M=(a,b)$ es el punto de intersección de los dos convexos distintos y la primera derivada parcial con respecto a $x$ es descontinua en el punto $M$. Esta función es contínuamente derivable en todas partes excepto en $M$, y cumple que esté contenida en los dos convexos.
#
# Problema: Determinar si es posible cubrir todo un disco circular de radio $R$ utilizando rectángulos right-angled, sin que las aristas de los rectángulos se interseprezcan y sin que se solapen los rectángulos entre sí.
# Solución: No es posible cubrir un disco circular utilizando rectángulos right-angled sin que se solapen o se interseprezcan las aristas de los rectángulos. Esto se puede demostrar mediante el Teorema de Heawood-Fejes Tóth, el cual indica que un disco con un radio cualquiera debe tener al menos $ i(n) = (1/4) [\frac{3π^2}{4} (n-1)^2 + 2(n-1)\pi + 1]$ regiones con vehicle cruzando para ser cubierta utilizando pentágoros o rectángulos right-angled. En el caso de rectángulos right-angled, se demostró recientemente que $i(n) \geq (9/2\sqrt{2})n (\frac{1}{2n} (\Gamma(n) - \Gamma(0)) + 1)$ regiones son necesarias, donde $\Gamma$ es la función gamma. En particular, como el Menor Primer Molde de los Números Primos (que es un límite para $n$ en la expresión de arriba) es infinito, es imposible cubrir el disco utilizando rectángulos right-angled sin solapamiento ni intersección de sus aristas.
#
# Problema: Demostrar que el conjunto de funciones de un espacio topológico $X$ que son continuamente derivables en $X$ es un ideal.
# Solución: Para probar que el conjunto de funciones de un espacio topológico $X$ que son continuamente derivables en $X$ es un ideal, se demostrará que es una subalgebra que cierra bajo la operación de Hausdorff para el supremo y la indecido para el infimum, y que bien su relación de continuidad está estrictamente relacionada con la continuidad inversa.
#
# Demostración:
#
# 1. Supongamos que $f,g$ son funciones continuamente derivables en $X$. Entonces, por la Regla de los Productos para la derivada:
#
#    $\frac{d(fg)}{dx} = f'g + fg'$
#
#    Donde $f',g'$ son las derivadas de $f$ e $g$ respectivamente. Por lo tanto, $f.g$ es una función derivable en $X$.
#
# 2. Supongamos que $c$ es un escalar. Entonces, si $f$ es derivable, entonces hay una función derivable $F$ tal que $F(x)=f(x) - C$. Así, por la Regla de la Suma para la derivada, $cf$ también es una función derivable.
#
# 3. Demuestra que $f^{-1}$ es derivable en $X$ si y solo si $f$ es una función inversa de una función derivable en $X$ y $f$ tiene propiedad inversa. La segunda condición se cumple si $f$ es una función bijectional con su imagen e inversa en $X$. Para la prueba de que $f^{-1}$ es derivable cuando $f$ es una función inversa de una función derivable $F$, se supone que $x,y$ están en $X$. Luego usando la propiedad de la inversa y la regla de la suma para la derivada:
#
#    $(f^{-1})'(y) = [ \frac{1}{F'(f^{-1}(y))} ]^{-1} = \frac{-1}{F'(f^{-1}(y))}$
#
#    Donde $F'(f^{-1}(y))$ es la derivada de la función inversa de $f$. Por lo tanto, $f^{-1}$ es derivable en $X$ si $f$ tiene propiedad inversa y $F$ es derivable en $X$.
#
# 4. Supongamos que la operación de Hausdorff para el supremo es realizada sobre el conjunto de funciones derivables. Si $f_n$ es una sucesión de funciones continuamente derivables y $f(x) = \sup_{n \in \mathbb{N}} f_n(x)$ para todo $x$ en $X$, entonces $f(x)$ es una función acotada y admite un limite no menor, según el teorema de Dini. Consta que este limite no menor es una función derivable en $X$, es decir, $f$ es derivable.
#
# 5. Supongamos que la operación de Hausdorff para el infimum es realizada sobre el conjunto de funciones derivables. Si $f_n$ es una sucesión de funciones continuamente derivables y $f(x) = \inf_{n \in \mathbb{N}} f_n(x)$ para todo $x$ en $X$, entonces $f(x)$ es una función con un límite no mayor y un valor mínimo interior en cada punto de $X$, según el teorema de Dini. Si $f_n$ tiene un límite no mayor en cada punto $x$, entonces $f$ es una función acotada, y por tanto $f$ es derivable en $X$. De lo contrario, suponiendo que $f$ no es derivable en $x_0$, entonces $f$ tiene una barriera $g$ en $x_0$. Permitiendole a $g$ tomar valores negativos iguales a $-1$ en un entorno de $x_0$, y $g$ tendrán al menos uno valor positivo en un entorno de $x_0$. Entonces, el punto limite superior de la sucesión $h_n = f_n + g$ debe ser positivo en $x_0$. Sin embargo, la sucesión $h_n$ también tiene límite no mayor en $x_0$, ya que la sucesión $f_n$ se acerca a $f$ en todo punto de $X$. Por lo tanto, $h_n$ tendría un límite no mayor posiblemente menor que cero en $x_0$, lo cual es una contradicción. Por lo tanto, $f$ debe ser derivable en $X$.
#
# Por lo tanto, el conjunto de todas las funciones continuamente derivables en el espacio topológico $X$ es un ideal.
#
#
# Generating 3 Geometría y Topología problem-solution pair(s)...
# Problema: Dado un polígono regular pentagonal. ¿Cuál es su número de vértices y su número de lados?
# Solución: El polígono regular pentagonal es un polígono de 5 lados y 5 vértices.
#
# Problema: Dados dos cilindros paralelos de radio r1 y r2, cuya altura es h. ¿Cálcula la superficie total de ambos cilindros.
# Solución: La superficie total es la suma de la superficie del cilindro exterior e interno. Cada cilindro tiene una superficie circular en cada extremo (2πr) y una superficie lateral (2πrh). Ambos cilindros tienen la misma superficie lateral (2πrh), así que la superficie total sería (4πrh + 2πr1 + 2πr2).
#
# Problema: Dado un}_6 comprendido por una esfera de radio r1 y la intersección con otros dos cilindros paralelos de radio r2. ¿Cuál es la longitud máxima del}_6?
# Solución: El}_6 se corresponde con el círculo de polea de la esfera con el cilindro paralelo, el cual es un círculo de radio r3. La longitud máxima del}_6 sería cuando este círculo de polea de radio r3 toque el centro de la esfera adjacent al cilindro, es decir 2r1 r3. Si no se encuentra en ese punto, se puede obtener a partir de la formula geométrica para la longitud máxima de un}_6 cuando está abierto parcialmente (según su posición con respecto al cilindro): (4r1r2 - r1^2 + r2^2)^(1/2).

# %% [markdown]
# **Exercise:** Using `nvidia/llama-3.1-nemotron-70b-reward`, filter the generated examples to retain only those that meet a certain quality threshold.

# %%
# Your code here

# %% [markdown]
# ---
# <h2 style="color:green;">Congratulations!</h2>
#
# In this notebook, you used Nemo Curator to generate math problems along with their solutions on a specific topic in both English and Spanish.
#
# <img src="./images/DLI_Header.png" style="width: 400px; float: right;">
